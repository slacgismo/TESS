# %%
import server;
# Out:
# response(target='endpoint_get_',kwargs={}) ->
# {
#     "hostname": "https://tess.slacgismo.io/",
#     "systems": [
#         "HCE"
#     ],
#     "limit": {
#         "anonymous": 60,
#         "authenticated": 3600
#     },
#     "endpoints": {
#         "config": {
#             "GET": [
#                 "/{system}",
#                 "/{system}?setting={parameter}",
#                 "/{system}/{resource}"
#             ],
#             "PUT": [
#                 "/{system}?setting={parameter}"
#             ]
#         },
#         "order": {
#             "GET": [
#                 "/{system}/{resource}",
#                 "/{system}/{resource}/{order}"
#             ],
#             "PUT": [
#                 "/{system}/{resource}",
#                 "/{system}/{resource}/{order}"
#             ],
#             "DELETE": [
#                 "/{system}/{resource}/{order}"
#             ]
#         },
#         "price": {
#             "GET": [
# ...

# %%
help('server')
# Out:
# Help on module server:
#
# NAME
#     server
#
# FUNCTIONS
#     endpoint_delete_order(db, **kwargs)
#
#     endpoint_get_(db, **kwargs)
#
#     endpoint_get_config(db, **kwargs)
#
#     endpoint_get_device(db, **kwargs)
#
#     endpoint_get_order(db, **kwargs)
#
#     endpoint_get_price(db, **kwargs)
#
#     endpoint_get_quantity(db, **kwargs)
#
#     endpoint_get_user(db, **kwargs)
#
#     endpoint_put_config(db, **kwargs)
#
#     endpoint_put_device(db, **kwargs)
#
#     endpoint_put_order(db, **kwargs)
#
#     endpoint_put_user(db, **kwargs)
#
#     process_request(verb, query, attributes=None, body=None)
#
#     response(target, **kwargs)
#
# DATA
#     endpoints = {'config': {'GET': ['/{system}', '/{system}?setting={param...
#     key = 'user'
#     value = {'GET': ['/{user}', '/{user}/{parameter}'], 'PUT': ['/{user}/{...
#     verb = 'PUT'
#
# FILE
#     /Users/david/GitHub/TESS/market/server.py
