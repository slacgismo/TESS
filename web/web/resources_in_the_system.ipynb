# %%
import pandas as pd

# %%
data = pd.read_csv('meter_intervals.csv', index_col=0, parse_dates=True)

# %%
hundred_precent = 24000.0

# %%
data
# Out:
#       is_bid  mode_dispatch  meter_id   qmtp           start_time  q_bid  \
# 0       True            0.0         1  0.000  2021-07-22T09:00:00    0.0
# 1       True            0.0         2  0.000  2021-07-22T09:00:00    0.0
# 2       True            0.0         3  0.000  2021-07-22T09:00:00    0.0
# 3       True            0.0         4  0.000  2021-07-22T09:00:00    0.0
# 4       True            0.0         5  0.000  2021-07-22T09:00:00    0.0
# ...      ...            ...       ...    ...                  ...    ...
# 2343    True            0.0         1  3.901  2021-09-21T13:04:04    0.0
# 2344    True            0.0         1  3.857  2021-09-21T13:09:05    0.0
# 2345    True            0.0         1  3.861  2021-09-21T13:14:06    0.0
# 2346    True            0.0         1  3.852  2021-09-21T13:19:06    0.0
# 2347    True            0.0         1  3.866  2021-09-21T13:24:07    0.0
#
#                  end_time  p_bid  mode_market  rate_id         e  \
# ...

# %%
data["qmtp"].sum()
# Out:
# 2147.41746
